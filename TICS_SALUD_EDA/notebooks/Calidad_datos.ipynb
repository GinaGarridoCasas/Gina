# %%
import pandas as pd
import numpy as np

# %%
Base_TICS_Salud = pd.read_csv("../Data/Base_completa.csv", sep =',')

# %%
# VALORES MISSING
missing_values_count = Base_TICS_Salud.isnull().sum()

# NO SE ENCUENTRAN MISSING VALUE

# missing_values_count

# %%
# ELIMINACION DE VALORES DUPLICADOS
Duplicados = Base_TICS_Salud.duplicated()

# NO SE ENCUENTRAN VALORES DUPLICADOS

# Duplicados

# %%
# VALORES OUTLIERS

import matplotlib.pyplot as plt

# Base_TICS_Salud.columns

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
# VALORES OUTLIERS VARIABLES TICS

plt.figure(figsize=(15,8))

boxplot = Base_TICS_Salud.boxplot(column=['ADSL','cable_fibra óptica','otras conexiones','conexion móvil_dispositivo_mano','móvil_USB'])
boxplot.plot()

plt.savefig("../reports/TICS_outliers.jpg", bbox_inches='tight')

# %%
plt.figure(figsize=(8,5))

boxplot = Base_TICS_Salud.boxplot(column=['Declaran acceso_internet_2017'])
boxplot.plot()

plt.savefig("../reports/TICS_outliers_1.jpg", bbox_inches='tight')

# %%
# Remove outliers variables TICS
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Declaran acceso_internet_2017')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'cable_fibra óptica')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'otras conexiones')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'móvil_USB')

# %%
plt.figure(figsize=(15,8))

boxplot = TICS_Salud_Liers.boxplot(column=['ADSL','cable_fibra óptica','otras conexiones','conexion móvil_dispositivo_mano','móvil_USB'])
boxplot.plot()

plt.savefig("../reports/TICS_Liers.jpg", bbox_inches='tight')

# %%
plt.figure(figsize=(15,8))

boxplot = TICS_Salud_Liers.boxplot(column=['Declaran acceso_internet_2017'])
boxplot.plot()

plt.savefig("../reports/TICS_Liers_1.jpg", bbox_inches='tight')
# Out:
# []

# %%
# SE MANTENDRÁN COMO VARIABLES TICS:

# ADSL, Cable_fibra óptica y conexión móvil_dispositivo_mano

# %%
# VALORES OUTLIERS VARIABLES SALUD 

# SALUD FÍSICA

plt.figure(figsize=(30,8))

boxplot = Base_TICS_Salud.boxplot(column=['Alguna Dificultad Conc','Mucha Dificultad Conc','Diabetes','Alguna Dificultad Ver','Mucha Dificultad Ver', 'Dolor espalda crónico cervical', 'Dolor espalda crónico lumbar', 'Infarto_miocardio', 'Restricc_AVD_Dolor', 'Sobrepeso', 'Migraña', 'Tension: alta'])
boxplot.plot()

plt.savefig("../reports/Salud_fisica_outliers.jpg", bbox_inches='tight')
# Out:
# []

# %%
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Alguna Dificultad Conc')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Mucha Dificultad Conc')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Diabetes')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Alguna Dificultad Ver')

TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Mucha Dificultad Ver')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Dolor espalda crónico cervical')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Dolor espalda crónico lumbar')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Infarto_miocardio')

TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Restricc_AVD_Dolor')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Sobrepeso')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Migraña')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Tension: alta')

# %%
plt.figure(figsize=(30,8))

boxplot = TICS_Salud_Liers.boxplot(column=['Alguna Dificultad Conc','Mucha Dificultad Conc','Diabetes','Alguna Dificultad Ver','Mucha Dificultad Ver', 'Dolor espalda crónico cervical', 'Dolor espalda crónico lumbar', 'Infarto_miocardio', 'Restricc_AVD_Dolor', 'Sobrepeso', 'Migraña', 'Tension: alta'])
boxplot.plot()

plt.savefig("../reports/Salud_fisica_Liers.jpg", bbox_inches='tight')
# Out:
# []

# %%
# SALUD MENTAL

plt.figure(figsize=(15,8))

boxplot = Base_TICS_Salud.boxplot(column=['Depresión', 'Ansiedad', 'Otros probl Salud_mental','Salud_mental: Media'])
boxplot.plot()

plt.savefig("../reports/Salud_mental_outliers.jpg", bbox_inches='tight')

# %%
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Depresión')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Ansiedad')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Otros probl Salud_mental')
TICS_Salud_Liers = remove_outlier(Base_TICS_Salud, 'Salud_mental: Media')

# %%
plt.figure(figsize=(15,8))

boxplot = TICS_Salud_Liers.boxplot(column=['Depresión', 'Ansiedad', 'Otros probl Salud_mental','Salud_mental: Media'])
boxplot.plot()

plt.savefig("../reports/Salud_mental_Liers.jpg", bbox_inches='tight')

# %%
TICS_Salud_Liers_1 = remove_outlier(TICS_Salud_Liers, 'Depresión')
TICS_Salud_Liers_1 = remove_outlier(TICS_Salud_Liers, 'Ansiedad')
TICS_Salud_Liers_1 = remove_outlier(TICS_Salud_Liers, 'Otros probl Salud_mental')
TICS_Salud_Liers_1 = remove_outlier(TICS_Salud_Liers, 'Salud_mental: Media')

# %%
plt.figure(figsize=(15,8))

boxplot = TICS_Salud_Liers_1.boxplot(column=['Depresión', 'Ansiedad', 'Otros probl Salud_mental','Salud_mental: Media'])
boxplot.plot()

plt.savefig("../reports/Salud_mental_Liers_1.jpg", bbox_inches='tight')

# %%
# VALORACIÓN SALUD: SALUD PERCIBIDA

plt.figure(figsize=(15,8))

boxplot = Base_TICS_Salud.boxplot(column=['Buena Salud', 'Salud Regular'])
boxplot.plot()

plt.savefig("../reports/Salud_percibida_outliers.jpg", bbox_inches='tight')
# Out:
# []

# %%
TICS_Salud_Liers = remove_outlier(TICS_Salud_Liers, 'Buena Salud')
TICS_Salud_Liers = remove_outlier(TICS_Salud_Liers, 'Salud Regular')

# %%
plt.figure(figsize=(15,8))

boxplot = TICS_Salud_Liers.boxplot(column=['Buena Salud', 'Salud Regular'])
boxplot.plot()

plt.savefig("../reports/Salud_percibida_Liers.jpg", bbox_inches='tight')

# %%
# VALORES OUTLIERS VARIABLES CONTROL
plt.figure(figsize=(15,8))

boxplot = Base_TICS_Salud.boxplot(column=['Renta_media_hogar'])
boxplot.plot()

plt.savefig("../reports/Renta_media_hogar_outliers.jpg", bbox_inches='tight')
# Out:
# []

# %%
plt.figure(figsize=(15,8))

boxplot = Base_TICS_Salud.boxplot(column=['Tasa_paro', 'Índice_masculinidad', 'Edad_25_59 años', 'Educacion_superior'])
boxplot.plot()

plt.savefig("../reports/Variables_control_outliers.jpg", bbox_inches='tight')
# Out:
# []

# %%
plt.figure(figsize=(15,8))

boxplot = Base_TICS_Salud.boxplot(column=['Índice_masculinidad'])
boxplot.plot()

plt.savefig("../reports/Indice_masculinidad_outliers.jpg", bbox_inches='tight')
# Out:
# []

# %%
plt.figure(figsize=(15,8))

boxplot = Base_TICS_Salud.boxplot(column=['Edad_25_59 años'])
boxplot.plot()

plt.savefig("../reports/Edad_25_59_outliers.jpg", bbox_inches='tight')
# Out:
# []
