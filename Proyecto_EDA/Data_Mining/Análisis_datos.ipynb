# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Base_TICS_Salud = pd.read_csv("../Data/Base_completa.csv", sep =',')
Base_TICS_Salud_Fisica = pd.read_csv("../Data/TICS_Salud_Física.csv", sep =',')
Base_TICS_Salud_Mental = pd.read_csv("../Data/TICS_Salud_Mental.csv", sep =',')
Base_TICS_Salud_Percibida = pd.read_csv("../Data/TICS_Salud_Percibida.csv", sep =',')
Base_TICS_Control = pd.read_csv("../Data/TICS_Control.csv", sep =',')

# %%
f, ax = plt.subplots(figsize=(13, 10))
sns.heatmap(Base_TICS_Salud_Fisica.corr(),
           vmin = -1,
           vmax = 1,
            annot = True,
           linewidths = .5)
# Out:
# <AxesSubplot:>

# %%
Base_TICS_Salud_Fisica.corr()
# Out:
#                                  Unnamed: 0  Declaran acceso_internet_2017  \
# Unnamed: 0                         1.000000                       0.300955
# Declaran acceso_internet_2017      0.300955                       1.000000
# ADSL                              -0.335977                      -0.013518
# cable_fibra óptica                 0.273722                       0.049927
# otras conexiones                   0.001662                       0.032954
# conexion móvil_dispositivo_mano   -0.202517                       0.001564
# móvil_USB                         -0.095066                      -0.083678
# Alguna Dificultad Conc            -0.028961                       0.058821
# Mucha Dificultad Conc             -0.042982                       0.150126
# Diabetes                          -0.136827                       0.078629
# Alguna Dificultad Ver             -0.164039                       0.105349
# ...

# %%
# Se encuentran correlaciones positivas superiores al 0.30 entre las variables:

    # cable_fibra óptica y Dolor de espalda crónico cervical (0.331009), Dolor de espalda crónico lumbar (0.423445), migraña (0.339201) y Sobrepeso (0,295572)
    # ADSL y Mucha dificultad para ver (0,295417)
    # Conexión móvil_dispositivo_mano y Mucha dificultad ver (0,358788)

# Se encuentran correlaciones negativas superiores al 0.30 entre las variables:

    # ADSL y Dolor espalda crónico cervical (-0,326843), lumbar (-0,392081) y migraña (-0,461299) y Mucha dificultas para ver (0,295417)
    # Cable_fibra óptica y Restricciones de la AVD por Dolor (-0,448099)
    # conexión móvil dispositivo de mano y Sobrepeso (-0,453489)
    # Otras conexiones y Dolor de espalda crónico lumbar (-0,327744), infarto de miocardio (-0,366746), migraña (-0,313308) y tensión alta (-0,723423)
    # Conexión móvil_dispositivo_mano y Sobrepeso (-0,453489)
    # móvil_USB y Alguna dificultad de concentración (-0,330843), Mucha dificultad de concentración (-0,338286), Dolor de espalda crónico lumbar (-0,44069), infarto de miocardio (-0,434670), migraña (-0,473593) y tensión alta (-0,481920)

# %%
Base_TICS_Salud_Mental.corr()
# Out:
#                                  Unnamed: 0  Declaran acceso_internet_2017  \
# Unnamed: 0                         1.000000                       0.300955
# Declaran acceso_internet_2017      0.300955                       1.000000
# ADSL                              -0.335977                      -0.013518
# cable_fibra óptica                 0.273722                       0.049927
# otras conexiones                   0.001662                       0.032954
# conexion móvil_dispositivo_mano   -0.202517                       0.001564
# móvil_USB                         -0.095066                      -0.083678
# Depresión                         -0.168546                       0.065711
# Ansiedad                          -0.360212                       0.049511
# Otros probl Salud_mental          -0.132411                       0.156953
# Salud_mental: Media                0.129284                       0.037242
#
#                                      ADSL  cable_fibra óptica  \
# ...

# %%
# Se encuentran correlaciones positivas superiores al 0.30 entre las variables:

    # cable_fibra óptica y Depresión (0.364424), Otros problemas de salud mental (0,299073)

# Se encuentran correlaciones negativas superiores al 0.30 entre las variables:

    # ADSL y depresión (-0,316051) y otros problemas de salud mental (-0,372779) 
    # Otras conexiones y depresión (-0,408917), ansiedad (-0,351730) y otros problemas de salud mental(-0,678278)
    # Móvil USB y otros problemas de salud mental (-0,550091)

# %%
Base_TICS_Salud_Percibida.corr()
# Out:
#                                  Unnamed: 0  Declaran acceso_internet_2017  \
# Unnamed: 0                         1.000000                       0.300955
# Declaran acceso_internet_2017      0.300955                       1.000000
# ADSL                              -0.335977                      -0.013518
# cable_fibra óptica                 0.273722                       0.049927
# otras conexiones                   0.001662                       0.032954
# conexion móvil_dispositivo_mano   -0.202517                       0.001564
# móvil_USB                         -0.095066                      -0.083678
# Buena Salud                       -0.052524                       0.096139
# Salud Regular                     -0.052524                       0.096139
#
#                                      ADSL  cable_fibra óptica  \
# Unnamed: 0                      -0.335977            0.273722
# Declaran acceso_internet_2017   -0.013518            0.049927
# ...

# %%
# Se encuentran correlaciones positivas superiores al 0.30 entre las variables:

    # Conexion móvil dispositiv_mano y Buena salud (0,293196) y salud regular (0,293196)

# Se encuentran correlaciones negativas superiores al 0.30 entre las variables:

    # Otras conexiones y Buena salud (- 0,533548) y salud regular (-0,533548)
    # Movil_USB y Buena salud (- 0,526708) y salud regular (- 0,526708)

# %%
Base_TICS_Control.corr()
# Out:
#                                  Unnamed: 0  Declaran acceso_internet_2017  \
# Unnamed: 0                         1.000000                       0.300955
# Declaran acceso_internet_2017      0.300955                       1.000000
# ADSL                              -0.335977                      -0.013518
# cable_fibra óptica                 0.273722                       0.049927
# otras conexiones                   0.001662                       0.032954
# conexion móvil_dispositivo_mano   -0.202517                       0.001564
# móvil_USB                         -0.095066                      -0.083678
# Renta_media_hogar                  0.296280                      -0.068753
# Tasa_paro                         -0.131552                       0.084550
# Índice_masculinidad                0.086043                      -0.079220
# Edad_25_59 años                   -0.258269                       0.066908
# ...

# %%
# Se encuentran correlaciones positivas superiores al 0.30 entre las variables:

    # ADSL y Tasa de paro (0,421448) e índice de masculinidad (0,437649)
    # Otras conexiones y Renta media_hogar (0,402015) y índice de masculinidad (0,400679)
    # Móvil_USB y Renta media_hogar (0,358863) y Indice de masculinidad (0,301825)

# Se encuentran correlaciones negativas superiores al 0.30 entre las variables:

    # ADSL y Educación superior (-0,346632)
    # Cable_fibra óptica y Tasa de paro (-0,396208) e índice masculinidad (-0,294156)
