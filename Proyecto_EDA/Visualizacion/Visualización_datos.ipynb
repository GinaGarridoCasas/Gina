# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Salud_Fisica = pd.read_csv("../Data/Bases/TICS_Salud_Física.csv", sep =',')
Salud_Mental = pd.read_csv("../Data/Bases/TICS_Salud_Mental.csv", sep =',')
Salud_Percibida = pd.read_csv("../Data/Bases/TICS_Salud_Percibida.csv", sep =',')
Control = pd.read_csv("../Data/Bases/TICS_Control.csv", sep =',')

# %%
Salud_Fisica.columns
# Out:
# Index(['Unnamed: 0', 'Declaran acceso_internet_2017', 'ADSL',
#        'cable_fibra óptica', 'otras conexiones',
#        'conexion móvil_dispositivo_mano', 'móvil_USB', 'index',
#        'Alguna Dificultad Conc', 'Mucha Dificultad Conc', 'Diabetes',
#        'Alguna Dificultad Ver', 'Mucha Dificultad Ver',
#        'Dolor espalda crónico cervical', 'Dolor espalda crónico lumbar',
#        'Infarto_miocardio', 'Restricc_AVD_Dolor', 'Sobrepeso', 'Migraña',
#        'Tension: alta'],
#       dtype='object')

# %%
plt.subplots(figsize=(13, 10))
sns.set(font_scale=1.5)
sns.heatmap(Salud_Percibida.corr(),
           vmin = -1,
           vmax = 1,
            annot = True,
           linewidths = .5)

plt.savefig("Salud_percibida.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Fisica['cable_fibra óptica'],Salud_Fisica['Dolor espalda crónico lumbar'], s=150,color="red")
plt.xlabel("cable_fibra óptica", fontsize = 20)
plt.ylabel("Dolor de espalda crónico lumbar", fontsize = 20)
plt.title("Banda ancha con cable o fibra óptica y dolor de espalda crónico lumbar",fontsize=25)
plt.tick_params(labelsize = 15)
for i, label in enumerate(annotations): 
    plt.text(Salud_Fisica['cable_fibra óptica'][i], Salud_Fisica['Dolor espalda crónico lumbar'][i],label,fontsize = 15)

plt.savefig("Fibra_Optica_Dolor_lumbar.jpg", bbox_inches='tight')

plt.show()

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Fisica['cable_fibra óptica'],Salud_Fisica['Dolor espalda crónico cervical'], s=150,color="red")
plt.xlabel("cable_fibra óptica", fontsize = 20)
plt.ylabel("Dolor de espalda crónico cervical", fontsize = 20)
plt.title("Banda ancha con cable o fibra óptica y dolor de espalda crónico cervical",fontsize=25)
plt.tick_params(labelsize = 15)
for i, label in enumerate(annotations):
    plt.text(Salud_Fisica['cable_fibra óptica'][i], Salud_Fisica['Dolor espalda crónico cervical'][i],label, fontsize = 15)


plt.savefig("Fibra_Optica_Dolor_cervical.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Fisica['cable_fibra óptica'],Salud_Fisica['Migraña'], s=150,color="red")
plt.xlabel("cable_fibra óptica", fontsize = 20)
plt.ylabel("Migraña", fontsize=20)
plt.title("Banda ancha con cable o fibra óptica y migraña",fontsize=25)
for i, label in enumerate(annotations):
    plt.text(Salud_Fisica['cable_fibra óptica'][i], Salud_Fisica['Migraña'][i],label, fontsize=15)
plt.tick_params(labelsize = 15)

plt.savefig("Fibra_Optica_migraña.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Fisica['cable_fibra óptica'],Salud_Fisica['Sobrepeso'], s=150,color="red")
plt.xlabel("cable_fibra óptica", fontsize = 20)
plt.ylabel("Sobrepeso", fontsize = 20)
plt.title("Banda ancha con cable o fibra óptica y sobrepeso",fontsize=25)
for i, label in enumerate(annotations):
    plt.text(Salud_Fisica['cable_fibra óptica'][i], Salud_Fisica['Sobrepeso'][i],label, fontsize =15)
plt.tick_params(labelsize=15)

plt.savefig("Fibra_Optica_Sobrepeso.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Fisica['ADSL'],Salud_Fisica['Mucha Dificultad Ver'], s=100,color="blue")
plt.xlabel("ADSL")
plt.ylabel("Mucha Dificultad Ver")
plt.title("Banda ancha con cable o fibra óptica y Mucha Dificultad Ver",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Salud_Fisica['ADSL'][i], Salud_Fisica['Mucha Dificultad Ver'][i],label)

plt.savefig("ADSL_Dificultad_ver.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Fisica['conexion móvil_dispositivo_mano'],Salud_Fisica['Mucha Dificultad Ver'], s=100,color="green")
plt.xlabel("conexion móvil_dispositivo_mano")
plt.ylabel("Mucha Dificultad Ver")
plt.title("Banda ancha con cable o fibra óptica y Mucha Dificultad Ver",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Salud_Fisica['conexion móvil_dispositivo_mano'][i], Salud_Fisica['Mucha Dificultad Ver'][i],label)

plt.savefig("Conexion_movil_Mano_Dificultad_ver.jpg", bbox_inches='tight')

# %%
# SALUD MENTAL

annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Mental['cable_fibra óptica'],Salud_Mental['Depresión'], s=150,color="blue")
plt.xlabel("cable_fibra óptica", fontsize = 20)
plt.ylabel("Depresión", fontsize = 20)
plt.title("Banda ancha con cable o fibra óptica y depresión",fontsize=25)
for i, label in enumerate(annotations):
    plt.text(Salud_Mental['cable_fibra óptica'][i], Salud_Mental['Depresión'][i],label, fontsize =15)
plt.tick_params(labelsize = 15)

plt.savefig("Fibra_Optica_Depresión.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Mental['cable_fibra óptica'],Salud_Mental['Otros probl Salud_mental'], s=100,color="blue")
plt.xlabel("cable_fibra óptica", fontsize =20)
plt.ylabel("Otros probl Salud_mental", fontsize =20)
plt.title("Banda ancha con cable o fibra óptica y otros probl Salud_mental",fontsize=25)
for i, label in enumerate(annotations):
    plt.text(Salud_Mental['cable_fibra óptica'][i], Salud_Mental['Otros probl Salud_mental'][i],label, fontsize =15)
plt.tick_params (labelsize =15)

plt.savefig("Fibra_Óptica_Otros_probl_salud_mental.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Salud_Percibida['conexion móvil_dispositivo_mano'],Salud_Percibida['Buena Salud'], s=100,color="green")
plt.xlabel("conexion móvil_dispositivo_mano")
plt.ylabel("Buena Salud")
plt.title("Banda ancha con cable o fibra óptica y Buena salud",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Salud_Percibida['conexion móvil_dispositivo_mano'][i], Salud_Percibida['Buena Salud'][i],label)

plt.savefig("conexion móvil_dispositivo_mano_Buena Salud.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Control['ADSL'],Control['Tasa_paro'], s=100,color="cyan")
plt.xlabel("ADSL")
plt.ylabel("Tasa_paro")
plt.title("ADSL y Tasa_paro",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Control['ADSL'][i], Control['Tasa_paro'][i],label)

plt.savefig("ADSL_Tasa_paro.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Control['ADSL'],Control['Índice_masculinidad'], s=100,color="cyan")
plt.xlabel("ADSL")
plt.ylabel("Índice_masculinidad")
plt.title("ADSL y Índice_masculinidad",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Control['ADSL'][i], Control['Índice_masculinidad'][i],label)

plt.savefig("ADSL_Índice_masculinidad.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Control['otras conexiones'],Control['Renta_media_hogar'], s=100,color="cyan")
plt.xlabel("otras conexiones")
plt.ylabel("Renta_media_hogar")
plt.title("otras conexiones y Renta_media_hogar",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Control['otras conexiones'][i], Control['Renta_media_hogar'][i],label)

plt.savefig("otras conexiones_Renta_media_hogar.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Control['otras conexiones'],Control['Índice_masculinidad'], s=100,color="cyan")
plt.xlabel("otras conexiones")
plt.ylabel("Índice_masculinidad")
plt.title("otras conexiones y Índice_masculinidad",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Control['otras conexiones'][i], Control['Índice_masculinidad'][i],label)

plt.savefig("otras conexiones_Índice_masculinidad.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Control['móvil_USB'],Control['Renta_media_hogar'], s=100,color="cyan")
plt.xlabel("móvil_USB")
plt.ylabel("Renta_media_hogar")
plt.title("móvil_USB y Renta_media_hogar",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Control['móvil_USB'][i], Control['Renta_media_hogar'][i],label)

plt.savefig("móvil_USB_Renta_media_hogar.jpg", bbox_inches='tight')

# %%
annotations=["Andalucía","Aragón","Asturias, Principado de","Balears, Illes","Canarias","Cantabria","Castilla y León","Castilla-La Mancha", "Cataluña","Ceuta","Comunitat Valenciana", "Extremadura","Galicia","Madrid, Comunidad de","Melilla","Murcia, Región de", "Navarra, Comunidad Foral de","País Vasco","Rioja, La", "Total nacional"]

plt.figure(figsize=(25,8))
plt.scatter(Control['móvil_USB'],Control['Índice_masculinidad'], s=100,color="cyan")
plt.xlabel("móvil_USB")
plt.ylabel("Índice_masculinidad")
plt.title("móvil_USB y Índice_masculinidad",fontsize=15)
for i, label in enumerate(annotations):
    plt.text(Control['móvil_USB'][i], Control['Índice_masculinidad'][i],label)

plt.savefig("móvil_USB_Índice_masculinidad.jpg", bbox_inches='tight')
